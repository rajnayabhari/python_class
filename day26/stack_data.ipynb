# %%
import pandas as pd
df=pd.read_csv("survey_results_public.csv")
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
df.shape
# Out:
# (88883, 85)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88883 entries, 0 to 88882
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              88883 non-null  int64
#  1   MainBranch              88331 non-null  object
#  2   Hobbyist                88883 non-null  object
#  3   OpenSourcer             88883 non-null  object
#  4   OpenSource              86842 non-null  object
#  5   Employment              87181 non-null  object
#  6   Country                 88751 non-null  object
#  7   Student                 87014 non-null  object
#  8   EdLevel                 86390 non-null  object
#  9   UndergradMajor          75614 non-null  object
#  10  EduOther                84260 non-null  object
#  11  OrgSize                 71791 non-null  object
#  12  DevType                 81335 non-null  object
#  13  YearsCode               87938 non-null  object
# ...

# %%
df.head(10)
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
# 5           6  I am not primarily a developer, but I write co...      Yes
# 6           7                     I am a developer by profession       No
# 7           8                        I code primarily as a hobby      Yes
# 8           9                     I am a developer by profession      Yes
# 9          10                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# ...

# %%
df.tail(10)
# Out:
#        Respondent MainBranch Hobbyist  \
# 88873       88062        NaN       No
# 88874       88076        NaN       No
# 88875       88182        NaN      Yes
# 88876       88212        NaN       No
# 88877       88282        NaN      Yes
# 88878       88377        NaN      Yes
# 88879       88601        NaN       No
# 88880       88802        NaN       No
# 88881       88816        NaN       No
# 88882       88863        NaN      Yes
#
#                                              OpenSourcer  \
# 88873                                              Never
# 88874                                              Never
# 88875                         Once a month or more often
# 88876                            Less than once per year
# 88877                         Once a month or more often
# 88878  Less than once a month but more than once per ...
# 88879                                              Never
# 88880                                              Never
# ...

# %%
df.iloc[0]
# Out:
# Respondent                                                      1
# MainBranch                 I am a student who is learning to code
# Hobbyist                                                      Yes
# OpenSourcer                                                 Never
# OpenSource      The quality of OSS and closed source software ...
#                                       ...
# Sexuality                                 Straight / Heterosexual
# Ethnicity                                                     NaN
# Dependents                                                     No
# SurveyLength                                Appropriate in length
# SurveyEase                             Neither easy nor difficult
# Name: 0, Length: 85, dtype: object

# %%
df.iloc[[0,1],2]
# Out:
# 0    Yes
# 1     No
# Name: Hobbyist, dtype: object

# %%
df.iloc[0:3]
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
#
#                OpenSourcer                                         OpenSource  \
# 0                    Never  The quality of OSS and closed source software ...
# 1  Less than once per year  The quality of OSS and closed source software ...
# 2                    Never  The quality of OSS and closed source software ...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
# 2                      Employed full-time                Thailand
#
#           Student                                            EdLevel  \
# ...

# %%
df.iloc[0:3,0:2]
# Out:
#    Respondent                                         MainBranch
# 0           1             I am a student who is learning to code
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...

# %%
df.iloc[5:9,6:10]
# Out:
#        Country Student                                            EdLevel  \
# 5       Canada      No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 6      Ukraine      No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 7        India     NaN           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 8  New Zealand      No  Some college/university study without earning ...
#
#                                       UndergradMajor
# 5                          Mathematics or statistics
# 6  Another engineering discipline (ex. civil, ele...
# 7  Computer science, computer engineering, or sof...
# 8  Computer science, computer engineering, or sof...

# %%
df.iloc[10:20,20:30]
# Out:
#                    MgrWant                                            JobSeek  \
# 10                     NaN                                                NaN
# 11                     NaN       I am not interested in new job opportunities
# 12                     NaN       I am not interested in new job opportunities
# 13                      No       I am not interested in new job opportunities
# 14                     NaN  I’m not actively looking, but I am open to new...
# 15                      No  I’m not actively looking, but I am open to new...
# 16                      No                    I am actively looking for a job
# 17                     Yes  I’m not actively looking, but I am open to new...
# 18                      No  I’m not actively looking, but I am open to new...
# 19  I am already a manager  I’m not actively looking, but I am open to new...
#
#              LastHireDate                                            LastInt  \
# ...

# %%
pd.set_option('display.max_columns',5)
pd.set_option('display.max_rows',10)
df
# Out:
#        Respondent                                         MainBranch  ...  \
# 0               1             I am a student who is learning to code  ...
# 1               2             I am a student who is learning to code  ...
# 2               3  I am not primarily a developer, but I write co...  ...
# 3               4                     I am a developer by profession  ...
# 4               5                     I am a developer by profession  ...
# ...           ...                                                ...  ...
# 88878       88377                                                NaN  ...
# 88879       88601                                                NaN  ...
# 88880       88802                                                NaN  ...
# 88881       88816                                                NaN  ...
# 88882       88863                                                NaN  ...
#
#                 SurveyLength                  SurveyEase
# ...

# %%
df.loc[0:3,"MainBranch":"SurveyEase"]
# Out:
#                                           MainBranch Hobbyist  ...  \
# 0             I am a student who is learning to code      Yes  ...
# 1             I am a student who is learning to code       No  ...
# 2  I am not primarily a developer, but I write co...      Yes  ...
# 3                     I am a developer by profession       No  ...
#
#             SurveyLength                  SurveyEase
# 0  Appropriate in length  Neither easy nor difficult
# 1  Appropriate in length  Neither easy nor difficult
# 2  Appropriate in length  Neither easy nor difficult
# 3  Appropriate in length                        Easy
#
# [4 rows x 84 columns]

# %%
df.loc[0:9,"MgrWant":"CompTotal"]
# Out:
#     MgrWant                                            JobSeek  ...  \
# 0       NaN                                                NaN  ...
# 1       NaN                    I am actively looking for a job  ...
# 2  Not sure  I’m not actively looking, but I am open to new...  ...
# 3  Not sure       I am not interested in new job opportunities  ...
# 4        No       I am not interested in new job opportunities  ...
# 5       Yes       I am not interested in new job opportunities  ...
# 6       NaN  I’m not actively looking, but I am open to new...  ...
# 7       NaN                                                NaN  ...
# 8  Not sure  I’m not actively looking, but I am open to new...  ...
# 9       Yes  I’m not actively looking, but I am open to new...  ...
#
#            CurrencyDesc CompTotal
# 0                   NaN       NaN
# 1                   NaN       NaN
# 2             Thai baht   23000.0
# 3  United States dollar   61000.0
# 4     Ukrainian hryvnia       NaN
# ...

# %%
df.set_index('Respondent',inplace=True)

# %%
df.sort_index(ascending=False)
# Out:
#                                                    MainBranch Hobbyist  ...  \
# Respondent                                                              ...
# 88883                          I am a developer by profession      Yes  ...
# 88882                          I am a developer by profession      Yes  ...
# 88881                          I am a developer by profession      Yes  ...
# 88880       I am not primarily a developer, but I write co...      Yes  ...
# 88879                          I am a developer by profession      Yes  ...
# ...                                                       ...      ...  ...
# 5                              I am a developer by profession      Yes  ...
# 4                              I am a developer by profession       No  ...
# 3           I am not primarily a developer, but I write co...      Yes  ...
# 2                      I am a student who is learning to code       No  ...
# ...

# %%
schema_df=pd.read_csv("survey_results_schema.csv",index_col="Column")
schema_df
# Out:
#                                                    QuestionText
# Column
# Respondent    Randomized respondent ID number (not in order ...
# MainBranch    Which of the following options best describes ...
# Hobbyist                                Do you code as a hobby?
# OpenSourcer         How often do you contribute to open source?
# OpenSource    How do you feel about the quality of open sour...
# ...                                                         ...
# Sexuality     Which of the following do you currently identi...
# Ethnicity     Which of the following do you identify as? Ple...
# Dependents    Do you have any dependents (e.g., children, el...
# SurveyLength  How do you feel about the length of the survey...
# SurveyEase    How easy or difficult was this survey to compl...
#
# [85 rows x 1 columns]

# %%
schema_df.loc[["MainBranch","Hobbyist","FizzBuzz","MgrIdiot"],"QuestionText"]
# Out:
# Column
# MainBranch    Which of the following options best describes ...
# Hobbyist                                Do you code as a hobby?
# FizzBuzz      Have you ever been asked to solve FizzBuzz in ...
# MgrIdiot      How confident are you that your manager knows ...
# Name: QuestionText, dtype: object

# %%
filt=(df["Age"]>40)
df.loc[filt]
# Out:
#                                 MainBranch Hobbyist  ...  \
# Respondent                                           ...
# 7           I am a developer by profession       No  ...
# 22          I am a developer by profession      Yes  ...
# 38          I am a developer by profession      Yes  ...
# 39          I am a developer by profession      Yes  ...
# 44          I am a developer by profession      Yes  ...
# ...                                    ...      ...  ...
# 82717                                  NaN       No  ...
# 83786                                  NaN       No  ...
# 85961                                  NaN      Yes  ...
# 86566                                  NaN      Yes  ...
# 87352                                  NaN      Yes  ...
#
#                      SurveyLength                  SurveyEase
# Respondent
# 7           Appropriate in length  Neither easy nor difficult
# 22          Appropriate in length                        Easy
# ...

# %%
df.loc[filt,["Age","Country","Student","LanguageWorkedWith"]]
# Out:
#              Age         Country Student  \
# Respondent
# 7           42.0         Ukraine      No
# 22          47.0   United States      No
# 38          44.0  Czech Republic      No
# 39          42.0   United States      No
# 44          43.0         Germany      No
# ...          ...             ...     ...
# 82717       44.0   United States      No
# 83786       57.0         Germany      No
# 85961       45.0  United Kingdom      No
# 86566       74.0     Switzerland      No
# 87352       59.0     Netherlands      No
#
#                                            LanguageWorkedWith
# Respondent
# 7                                         HTML/CSS;JavaScript
# 22          Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# 38                                 C#;HTML/CSS;JavaScript;SQL
# 39                               C#;JavaScript;SQL;TypeScript
# 44          Bash/Shell/PowerShell;C#;HTML/CSS;Java;JavaScr...
# ...                                                       ...
# ...

# %%
# first method
filt=(df["Country"]=="India")|(["Country"]=="Canada")
df.loc[filt,["Age","Country","Student","LanguageWorkedWith"]]
# Out:
#              Age Country         Student  \
# Respondent
# 8           24.0   India             NaN
# 10           NaN   India              No
# 15          20.0   India  Yes, full-time
# 50          23.0   India              No
# 65          21.0   India              No
# ...          ...     ...             ...
# 77339        NaN   India  Yes, full-time
# 79795        NaN   India              No
# 83862       24.0   India  Yes, full-time
# 84299        NaN   India  Yes, full-time
# 86012       24.0   India              No
#
#                                            LanguageWorkedWith
# Respondent
# 8           Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 10                              C#;Go;JavaScript;Python;R;SQL
# 15          Assembly;Bash/Shell/PowerShell;C;C++;HTML/CSS;...
# 50          Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 65                            Assembly;C;C++;C#;HTML/CSS;Java
# ...                                                       ...
# ...

# %%
# second and sajilo method
countries=["India","United Kingdom","Canada","Thailand"]
filt=df["Country"].isin(countries)
df.loc[filt,["Age","Country","Student","LanguageWorkedWith"]]
# Out:
#              Age         Country         Student  \
# Respondent
# 1           14.0  United Kingdom              No
# 3           28.0        Thailand              No
# 6           28.0          Canada              No
# 8           24.0           India             NaN
# 10           NaN           India              No
# ...          ...             ...             ...
# 84539       23.0  United Kingdom  Yes, full-time
# 85182        NaN          Canada             NaN
# 85961       45.0  United Kingdom              No
# 86012       24.0           India              No
# 88377        NaN          Canada              No
#
#                                            LanguageWorkedWith
# Respondent
# 1                             HTML/CSS;Java;JavaScript;Python
# 3                                                    HTML/CSS
# 6                                                  Java;R;SQL
# 8           Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# ...

# %%
filt=df["Country"].isin(countries)&df["LanguageWorkedWith"].str.contains("Python")
df.loc[filt,["Age","Country","Student","LanguageWorkedWith"]]
# Out:
#              Age         Country         Student  \
# Respondent
# 1           14.0  United Kingdom              No
# 8           24.0           India             NaN
# 10           NaN           India              No
# 12          21.0          Canada  Yes, full-time
# 21           NaN          Canada             NaN
# ...          ...             ...             ...
# 79798       22.0  United Kingdom  Yes, full-time
# 82007       40.0          Canada             NaN
# 82789       17.0  United Kingdom              No
# 84299        NaN           India  Yes, full-time
# 84539       23.0  United Kingdom  Yes, full-time
#
#                                            LanguageWorkedWith
# Respondent
# 1                             HTML/CSS;Java;JavaScript;Python
# 8           Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 10                              C#;Go;JavaScript;Python;R;SQL
# 12           Bash/Shell/PowerShell;HTML/CSS;Java;Python;R;SQL
# ...
